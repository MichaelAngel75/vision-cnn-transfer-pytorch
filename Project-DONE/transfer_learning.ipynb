# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Transfer learning
#
# In the previous notebook we have trained our own CNN and we got a certain performance. Let's see how hard it is to match that performance with transfer learning.
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly and check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
import pkg_resources

for package in ["setuptools", "wheel", "cmake", "scikit-build"]:
    try:
        version = pkg_resources.get_distribution(package).version
        print(f"{package}: {version}")
    except pkg_resources.DistributionNotFound:
        print(f"{package}: NOT INSTALLED")
# ----- IT WORKS --------
# setuptools: 45.2.0.post20200209
# wheel: 0.34.2
# cmake: NOT INSTALLED
# scikit-build: NOT INSTALLED    
# ---- DOESN'T WORK -----
# setuptools: 80.9.0
# wheel: 0.45.1
# Out:
# setuptools: 69.0.3
# wheel: 0.42.0
# cmake: NOT INSTALLED
# scikit-build: NOT INSTALLED
# /home/sagemaker-user/.conda/envs/py37_env_02/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   """Entry point for launching an IPython kernel.

# %%
# !python -V
import sys
# !{sys.executable} -V
# Out:
# Python 3.7.6

# %%
#  The build process requires specific versions of setuptools, wheel, cmake, and scikit-build to work correctly.
# Install requirements
# !{sys.executable} -m pip install -r requirements.txt | grep -v "already satisfied"
# Out:
# Collecting matplotlib==3.4.3 (from -r requirements.txt (line 2))
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl.metadata (5.7 kB)
# Collecting numpy==1.21.2 (from -r requirements.txt (line 3))
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.1 kB)
# Collecting pillow==7.0.0 (from -r requirements.txt (line 4))
#   Downloading Pillow-7.0.0-cp37-cp37m-manylinux1_x86_64.whl.metadata (5.5 kB)
# Collecting bokeh==2.1.1 (from -r requirements.txt (line 5))
#   Downloading bokeh-2.1.1.tar.gz (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 97.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting torch==1.11.0 (from -r requirements.txt (line 6))
#   Downloading torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.12.0 (from -r requirements.txt (line 7))
#   Downloading torchvision-0.12.0-cp37-cp37m-manylinux1_x86_64.whl.metadata (10 kB)
# Collecting tqdm==4.63.0 (from -r requirements.txt (line 8))
#   Downloading tqdm-4.63.0-py2.py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 12.6 MB/s eta 0:00:00
# Collecting ipywidgets==7.6.5 (from -r requirements.txt (line 9))
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting livelossplot==0.5.4 (from -r requirements.txt (line 10))
#   Downloading livelossplot-0.5.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting pytest==7.1.1 (from -r requirements.txt (line 11))
#   Downloading pytest-7.1.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandas==1.3.5 (from -r requirements.txt (line 12))
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting seaborn==0.11.2 (from -r requirements.txt (line 13))
#   Downloading seaborn-0.11.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting cycler>=0.10 (from matplotlib==3.4.3->-r requirements.txt (line 2))
#   Downloading cycler-0.11.0-py3-none-any.whl.metadata (785 bytes)
# Collecting kiwisolver>=1.0.1 (from matplotlib==3.4.3->-r requirements.txt (line 2))
#   Downloading kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.2.1 (from matplotlib==3.4.3->-r requirements.txt (line 2))
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Collecting PyYAML>=3.10 (from bokeh==2.1.1->-r requirements.txt (line 5))
#   Downloading PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting Jinja2>=2.7 (from bokeh==2.1.1->-r requirements.txt (line 5))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing_extensions>=3.7.4 (from bokeh==2.1.1->-r requirements.txt (line 5))
#   Downloading typing_extensions-4.7.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting requests (from torchvision==0.12.0->-r requirements.txt (line 7))
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting nbformat>=4.2.0 (from ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading nbformat-5.8.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting widgetsnbextension~=3.5.0 (from ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting jupyterlab-widgets>=1.0.0 (from ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting attrs>=19.2.0 (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting iniconfig (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading pluggy-1.2.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting py>=1.8.2 (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting tomli>=1.0.0 (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting importlib-metadata>=0.12 (from pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting pytz>=2017.3 (from pandas==1.3.5->-r requirements.txt (line 12))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy>=1.0 (from seaborn==0.11.2->-r requirements.txt (line 13))
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (2.2 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=0.12->pytest==7.1.1->-r requirements.txt (line 11))
#   Downloading zipp-3.15.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.7->bokeh==2.1.1->-r requirements.txt (line 5))
#   Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting fastjsonschema (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting jsonschema>=2.6 (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading jsonschema-4.17.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading notebook-6.5.7-py3-none-any.whl.metadata (2.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests->torchvision==0.12.0->-r requirements.txt (line 7))
#   Downloading charset_normalizer-3.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision==0.12.0->-r requirements.txt (line 7))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->torchvision==0.12.0->-r requirements.txt (line 7))
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision==0.12.0->-r requirements.txt (line 7))
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-resources>=1.4.0 (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading importlib_resources-5.12.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading pyrsistent-0.19.3-py3-none-any.whl.metadata (27 kB)
# Collecting argon2-cffi (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting nbconvert>=5 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading nbconvert-7.6.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting Send2Trash>=1.8.0 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading terminado-0.17.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting prometheus-client (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading prometheus_client-0.17.1-py3-none-any.whl.metadata (24 kB)
# Collecting nbclassic>=0.4.7 (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading nbclassic-1.2.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting notebook-shim>=0.2.3 (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting beautifulsoup4 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading bleach-6.0.0-py3-none-any.whl.metadata (29 kB)
# Collecting defusedxml (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading nbclient-0.7.4-py3-none-any.whl.metadata (7.9 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading tinycss2-1.2.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting jupyter-server<3,>=1.8 (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading jupyter_server-1.24.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading cffi-1.15.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading soupsieve-2.4.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading pycparser-2.21-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting anyio<4,>=3.1.0 (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading websocket_client-1.6.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting sniffio>=1.1 (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9))
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 108.1 MB/s eta 0:00:00
# Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 97.3 MB/s eta 0:00:00
# Downloading Pillow-7.0.0-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 115.6 MB/s eta 0:00:00
# Downloading torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl (750.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 1.9 MB/s eta 0:00:00
# Downloading torchvision-0.12.0-cp37-cp37m-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 91.5 MB/s eta 0:00:00
# Downloading tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 kB 17.0 MB/s eta 0:00:00
# Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.8/121.8 kB 25.8 MB/s eta 0:00:00
# Downloading livelossplot-0.5.4-py3-none-any.whl (22 kB)
# Downloading pytest-7.1.1-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.0/297.0 kB 53.2 MB/s eta 0:00:00
# Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 137.5 MB/s eta 0:00:00
# Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 48.2 MB/s eta 0:00:00
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 15.1 MB/s eta 0:00:00
# Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 30.7 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 43.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 103.9 MB/s eta 0:00:00
# Downloading nbformat-5.8.0-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 18.3 MB/s eta 0:00:00
# Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 22.4 MB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 24.5 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 71.4 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 78.2 MB/s eta 0:00:00
# Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 74.4 MB/s eta 0:00:00
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 98.1 MB/s eta 0:00:00
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 12.9 MB/s eta 0:00:00
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.7/157.7 kB 28.3 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.3/141.3 kB 26.1 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 15.3 MB/s eta 0:00:00
# Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 19.2 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading notebook-6.5.7-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 68.8 MB/s eta 0:00:00
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 24.7 MB/s eta 0:00:00
# Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Downloading nbclassic-1.2.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 134.7 MB/s eta 0:00:00
# Downloading nbconvert-7.6.0-py3-none-any.whl (290 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 46.9 MB/s eta 0:00:00
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 11.7 MB/s eta 0:00:00
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading prometheus_client-0.17.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 13.9 MB/s eta 0:00:00
# Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 33.0 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 10.6 MB/s eta 0:00:00
# Downloading nbclient-0.7.4-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 15.0 MB/s eta 0:00:00
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 19.3 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 37.8 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Downloading cffi-1.15.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 65.6 MB/s eta 0:00:00
# Downloading jupyter_server-1.24.0-py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.5/347.5 kB 50.8 MB/s eta 0:00:00
# Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 17.4 MB/s eta 0:00:00
# Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 23.7 MB/s eta 0:00:00
# Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 13.0 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Building wheels for collected packages: bokeh
#   Building wheel for bokeh (setup.py): started
#   Building wheel for bokeh (setup.py): finished with status 'done'
#   Created wheel for bokeh: filename=bokeh-2.1.1-py3-none-any.whl size=9257172 sha256=77454eb9f85158492348eac934b16ee03a47967fbb3074581d9e74f00589b876
#   Stored in directory: /home/sagemaker-user/.cache/pip/wheels/f7/55/ff/f3d7554e69382d31cf7ad857cf518af9b923134fca7d925187
# Successfully built bokeh
# Installing collected packages: webencodings, pytz, ipython-genutils, fastjsonschema, zipp, websocket-client, urllib3, typing_extensions, tqdm, tomli, tinycss2, terminado, soupsieve, sniffio, Send2Trash, PyYAML, pyrsistent, pyparsing, pycparser, py, prometheus-client, pkgutil-resolve-name, pillow, pandocfilters, numpy, mistune, MarkupSafe, jupyterlab-widgets, jupyterlab-pygments, iniconfig, idna, defusedxml, cycler, charset-normalizer, certifi, bleach, torch, scipy, requests, pandas, kiwisolver, Jinja2, importlib-resources, importlib-metadata, exceptiongroup, cffi, beautifulsoup4, torchvision, pluggy, matplotlib, bokeh, attrs, argon2-cffi-bindings, anyio, seaborn, pytest, livelossplot, jsonschema, argon2-cffi, nbformat, nbclient, nbconvert, jupyter-server, notebook-shim, nbclassic, notebook, widgetsnbextension, ipywidgets
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# Successfully installed Jinja2-3.1.6 MarkupSafe-2.1.5 PyYAML-6.0.1 Send2Trash-1.8.3 anyio-3.7.1 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 attrs-24.2.0 beautifulsoup4-4.13.4 bleach-6.0.0 bokeh-2.1.1 certifi-2025.6.15 cffi-1.15.1 charset-normalizer-3.4.2 cycler-0.11.0 defusedxml-0.7.1 exceptiongroup-1.3.0 fastjsonschema-2.21.1 idna-3.10 importlib-metadata-6.7.0 importlib-resources-5.12.0 iniconfig-2.0.0 ipython-genutils-0.2.0 ipywidgets-7.6.5 jsonschema-4.17.3 jupyter-server-1.24.0 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.15 kiwisolver-1.4.5 livelossplot-0.5.4 matplotlib-3.4.3 mistune-3.0.2 nbclassic-1.2.0 nbclient-0.7.4 nbconvert-7.6.0 nbformat-5.8.0 notebook-6.5.7 notebook-shim-0.2.4 numpy-1.21.2 pandas-1.3.5 pandocfilters-1.5.1 pillow-7.0.0 pkgutil-resolve-name-1.3.10 pluggy-1.2.0 prometheus-client-0.17.1 py-1.11.0 pycparser-2.21 pyparsing-3.1.4 pyrsistent-0.19.3 pytest-7.1.1 pytz-2025.2 requests-2.31.0 scipy-1.7.3 seaborn-0.11.2 sniffio-1.3.1 soupsieve-2.4.1 terminado-0.17.1 tinycss2-1.2.1 tomli-2.0.1 torch-1.11.0 torchvision-0.12.0 tqdm-4.63.0 typing_extensions-4.7.1 urllib3-2.0.7 webencodings-0.5.1 websocket-client-1.6.1 widgetsnbextension-3.5.2 zipp-3.15.0

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU available
# Downloading and unzipping https://udacity-dlnfd.s3-us-west-1.amazonaws.com/datasets/landmark_images.zip. This will take a while...
# done
# Computing mean: 100%|██████████████████████| 6246/6246 [00:59<00:00, 104.24it/s]
# Computing std: 100%|███████████████████████| 6246/6246 [01:01<00:00, 101.03it/s]

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Create transfer learning architecture
#
# Open the file `src/transfer.py` and complete the `get_model_transfer_learning` function. When you are done, execute this test:

# %%
# !pytest -vv src/transfer.py
import sys
# !{sys.executable} -m pytest -vv src/transfer.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- /home/sagemaker-user/.conda/envs/py37_env_02/bin/python
# cachedir: .pytest_cache
# rootdir: /home/sagemaker-user
# plugins: anyio-3.7.1
# collected 1 item
#
# src/transfer.py::test_get_model_transfer_learning PASSED                 [100%]
#
# =============================== warnings summary ===============================
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
#   /home/sagemaker-user/.conda/envs/py37_env_02/lib/python3.7/site-packages/matplotlib/__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
#   /home/sagemaker-user/.conda/envs/py37_env_02/lib/python3.7/site-packages/setuptools/_distutils/version.py:345: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================== 1 passed, 10 warnings in 1.79s ========================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Train, validation and test
#
# Let's train our transfer learning model! Let's start defining the hyperparameters:

# %%
batch_size = 64  # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2  # fraction of the training data to reserve for validation
num_epochs = 6  # number of epochs for training
num_classes = 50  # number of classes. Do not change this
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'      # optimizer. 'sgd' or 'adam'
weight_decay = 0.0 # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.optimization import get_optimizer, get_loss
from src.train import optimize
from src.transfer import get_model_transfer_learning

# Get a model using get_model_transfer_learning. Use one of the names reported here:
# https://pytorch.org/vision/0.10/models.html
# For example, if you want to load ResNet 18, use "resnet18"
# NOTE: use the hyperparameters defined in the previous cell, do NOT copy/paste the
# values
model_transfer = get_model_transfer_learning(model_name="resnet18", n_classes=num_classes) # YOUR CODE HERE

# train the model
data_loaders = get_data_loaders(batch_size=batch_size)
optimizer = get_optimizer(
    model_transfer,
    learning_rate=learning_rate,
    optimizer=opt,
    weight_decay=weight_decay,
)
loss = get_loss()

optimize(
    data_loaders,
    model_transfer,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/model_transfer.pt",
    interactive_tracking=True
)

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> __Question:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/>  __Answer:__

# %% [markdown]
# Now play with the hyperparameters and see which performance you can get on the validation set. You should get at least 60% for a passing grade, but a good model choice and a good training strategy could get you up to 80% or so. Let's see how close you can get!

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: Test the Model
#
# Try out your model on the test dataset of landmark images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60% and matches more or less what you got on the validation set (otherwise you're overfitting!)

# %%
import torch
from src.train import one_epoch_test
from src.transfer import get_model_transfer_learning

model_transfer = get_model_transfer_learning("resnet18", n_classes=num_classes)
# Load saved weights
model_transfer.load_state_dict(torch.load('checkpoints/model_transfer.pt'))

one_epoch_test(data_loaders['test'], model_transfer, loss)
# Out:
# Testing: 100%|██████████████████████████████████| 20/20 [00:13<00:00,  1.44it/s]
# Test Loss: 1.119634
#
#
# Test Accuracy: 72% (904/1250)
# 1.1196344554424287

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Export using torchscript
#
# Now, just like we did with our original model, we export the best fit model using torchscript so that it can be used in our application:

# %%
from src.predictor import Predictor
from src.helpers import compute_mean_and_std

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model_transfer = model_transfer.cpu()

# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)
model_transfer.load_state_dict(
    torch.load("checkpoints/model_transfer.pt", map_location="cpu")
)

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model_transfer, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)
scripted_predictor.save("checkpoints/transfer_exported.pt")
# Out:
# Reusing cached mean and std

# %%
import torch
from src.predictor import predictor_test
from src.helpers import plot_confusion_matrix

model_reloaded = torch.jit.load("checkpoints/transfer_exported.pt")

pred, truth = predictor_test(data_loaders['test'], model_reloaded)

plot_confusion_matrix(pred, truth)
# Out:
# 100%|███████████████████████████████████████| 1250/1250 [00:32<00:00, 38.22it/s]
# Accuracy: 0.6856

# %%
from src.create_submit_pkg import create_submit_pkg
create_submit_pkg()
# Out:
# executing: jupyter nbconvert --to html app.ipynb
# [NbConvertApp] Converting notebook app.ipynb to html
# /opt/conda/lib/python3.12/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# [NbConvertApp] Writing 291797 bytes to app.html
# executing: jupyter nbconvert --to html transfer_learning.ipynb
# [NbConvertApp] Converting notebook transfer_learning.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 513441 bytes to transfer_learning.html
# executing: jupyter nbconvert --to html cnn_from_scratch.ipynb
# [NbConvertApp] Converting notebook cnn_from_scratch.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 2 image(s).
# [NbConvertApp] Writing 833282 bytes to cnn_from_scratch.html
# executing: jupyter nbconvert --to html Prepare-environment.ipynb
# [NbConvertApp] Converting notebook Prepare-environment.ipynb to html
# [NbConvertApp] Writing 293063 bytes to Prepare-environment.html
# Adding files to submission_2025-06-28T03h34m.tar.gz
# src/optimization.py
# src/data.py
# src/predictor.py
# src/model.py
# src/transfer.py
# src/train.py
# src/create_submit_pkg.py
# src/helpers.py
# src/__init__.py
# app.ipynb
# transfer_learning.ipynb
# cnn_from_scratch.ipynb
# Prepare-environment.ipynb
# app.html
# transfer_learning.html
# cnn_from_scratch.html
# Prepare-environment.html
#
# ----------------------------------------------------------------
# Done. Please submit the file submission_2025-06-28T03h34m.tar.gz
# ----------------------------------------------------------------
